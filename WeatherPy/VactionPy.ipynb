# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %%
#Name dataframe for cleaned data csv
csv = "cities.csv"

#Read the data
cities_df = pd.read_csv(csv)

# %%
cities_df.head()
# Out:
#    Unnamed: 0             City  Temperature  Humidity  Cloudiness  Wind Speed  \
# 0           0  Severo-Kuril'sk        26.74        91          28       17.47
# 1           1             Chui        66.29        81           2        9.91
# 2           2        Kavaratti        86.02        64           1        2.08
# 3           3          Mataura        44.01        82          45        7.00
# 4           4        Tuatapere        44.01        82          54        7.00
#
#    Latitude  Longitude
# 0     50.68     156.12
# 1    -33.70     -53.46
# 2     10.57      72.64
# 3    -46.19     168.86
# 4    -46.13     167.68

# %%
locations = cities_df[['Latitude','Longitude']].astype(float)
cities_df = cities_df.dropna()
humidity = cities_df['Humidity'].astype(float)

# %%
gmaps.configure(api_key=g_key)

# %%
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
cities_df.head()
# Out:
#    Unnamed: 0             City  Temperature  Humidity  Cloudiness  Wind Speed  \
# 0           0  Severo-Kuril'sk        26.74        91          28       17.47
# 1           1             Chui        66.29        81           2        9.91
# 2           2        Kavaratti        86.02        64           1        2.08
# 3           3          Mataura        44.01        82          45        7.00
# 4           4        Tuatapere        44.01        82          54        7.00
#
#    Latitude  Longitude
# 0     50.68     156.12
# 1    -33.70     -53.46
# 2     10.57      72.64
# 3    -46.19     168.86
# 4    -46.13     167.68

# %%
temp = cities_df.loc[cities_df["Temperature"] >=70, :]
temp
# Out:
#      Unnamed: 0         City  Temperature  Humidity  Cloudiness  Wind Speed  \
# 2             2    Kavaratti        86.02        64           1        2.08
# 6             6      Qandala        86.68        61          62        8.99
# 8             8      Garissa        89.22        51         100       18.97
# 11           11      Rikitea        76.73        69          53        6.91
# 15           15        Vaini        77.00        88          40        5.82
# ..          ...          ...          ...       ...         ...         ...
# 542         542   Eydhafushi        85.96        74          61       11.27
# 543         543         Kaka        78.04        21           6        6.85
# 549         549    Pontianak        82.40        74          40        4.70
# 550         550  San Ignacio        74.61        94           5        2.28
# 552         552   São Filipe        72.64        69          24       17.02
#
#      Latitude  Longitude
# 2       10.57      72.64
# 6       11.47      49.87
# 8       -0.45      39.64
# 11     -23.12    -134.97
# 15     -21.20    -175.20
# ..        ...        ...
# 542      5.10      73.07
# 543     37.35      59.61
# 549     -0.03     109.33
# 550     17.16     -89.07
# 552     14.90     -24.50
#
# [248 rows x 8 columns]

# %%
perfecttemp = temp.loc[temp["Temperature"] <=80, :]
perfecttemp
# Out:
#      Unnamed: 0          City  Temperature  Humidity  Cloudiness  Wind Speed  \
# 11           11       Rikitea        76.73        69          53        6.91
# 15           15         Vaini        77.00        88          40        5.82
# 16           16  Puerto Ayora        78.89        94          40        9.17
# 22           22     Les Cayes        79.57        75          11        8.81
# 42           42      Ajdabiya        77.07        27           1        3.40
# ..          ...           ...          ...       ...         ...         ...
# 540         540      Pavlodar        75.20        17          94        2.24
# 541         541          Naze        71.60        94          75        9.17
# 543         543          Kaka        78.04        21           6        6.85
# 550         550   San Ignacio        74.61        94           5        2.28
# 552         552    São Filipe        72.64        69          24       17.02
#
#      Latitude  Longitude
# 11     -23.12    -134.97
# 15     -21.20    -175.20
# 16      -0.74     -90.35
# 22      18.20     -73.75
# 42      30.76      20.23
# ..        ...        ...
# 540     52.30      76.95
# 541     28.37     129.48
# 543     37.35      59.61
# 550     17.16     -89.07
# 552     14.90     -24.50
#
# [111 rows x 8 columns]

# %%
lowwind = perfecttemp.loc[perfecttemp['Wind Speed'] <10, :]
lowwind
# Out:
#      Unnamed: 0          City  Temperature  Humidity  Cloudiness  Wind Speed  \
# 11           11       Rikitea        76.73        69          53        6.91
# 15           15         Vaini        77.00        88          40        5.82
# 16           16  Puerto Ayora        78.89        94          40        9.17
# 22           22     Les Cayes        79.57        75          11        8.81
# 42           42      Ajdabiya        77.07        27           1        3.40
# ..          ...           ...          ...       ...         ...         ...
# 539         539     Boyolangu        79.74        83          88        3.06
# 540         540      Pavlodar        75.20        17          94        2.24
# 541         541          Naze        71.60        94          75        9.17
# 543         543          Kaka        78.04        21           6        6.85
# 550         550   San Ignacio        74.61        94           5        2.28
#
#      Latitude  Longitude
# 11     -23.12    -134.97
# 15     -21.20    -175.20
# 16      -0.74     -90.35
# 22      18.20     -73.75
# 42      30.76      20.23
# ..        ...        ...
# 539     -8.12     111.89
# 540     52.30      76.95
# 541     28.37     129.48
# 543     37.35      59.61
# 550     17.16     -89.07
#
# [81 rows x 8 columns]

# %%
noclouds = lowwind.loc[lowwind['Cloudiness'] <1, :]
perfectweather = noclouds
perfectweather
# Out:
#      Unnamed: 0          City  Temperature  Humidity  Cloudiness  Wind Speed  \
# 74           74    Media Luna        78.06        72           0        3.27
# 181         181  Bull Savanna        75.13        76           0        7.83
# 186         186         Paita        72.68        76           0        8.66
# 246         246    Oranjemund        71.98        54           0        8.37
# 439         439   Georgiyevka        73.40        28           0        8.95
# 529         529       Dustlik        77.65        21           0        4.99
# 532         532      Lüderitz        75.20        50           0        6.93
#
#      Latitude  Longitude
# 74      20.14     -77.44
# 181     17.89     -77.59
# 186     -5.09     -81.11
# 246    -28.55      16.43
# 439     43.04      74.71
# 529     40.52      68.04
# 532    -26.65      15.16
